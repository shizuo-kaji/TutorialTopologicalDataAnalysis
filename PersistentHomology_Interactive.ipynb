# %% [markdown]
# <a href="https://colab.research.google.com/github/shizuo-kaji/TutorialTopologicalDataAnalysis/blob/master/PersistentHomology_Interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interactive Persistent Homology
#
# This notebook is an interactive explainer of **persistent homology (PH)** across several kinds of filtered complexes:
#
# 1. **Vietoris-Rips (VR) complexes** for 2D point clouds -- watch edges and triangles appear as the scale $\varepsilon$ grows.
# 2. **Weighted graphs** as 1-dimensional simplicial complexes -- the same idea, but starting from an arbitrary weighted graph instead of a metric point cloud, and stopping at edges so every loop found is permanent.
# 3. **Cubical complexes** for 1D signals and 2D images, including two real, non-trivial images (counting coins, finding holes in letters).
# 4. **3D point clouds** -- a bonus look at $H_2$ (enclosed voids), sampled from the surface of simple 3D shapes.
#
# Throughout, we connect geometric/combinatorial features with births and deaths in the barcode and persistence diagram, and track a single filtration value with a slider.

# %%
# !pip install -U cripser ripser gudhi networkx scikit-image

# %%
import itertools
from functools import lru_cache
from typing import Dict, List, Tuple

import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.collections import LineCollection, PolyCollection
from matplotlib.patches import Circle
from ripser import ripser
from scipy.spatial.distance import pdist, squareform

plt.rcParams["figure.dpi"] = 120
plt.rcParams["axes.grid"] = True

# %% [markdown]
# ## Core helpers (shared by every section below)
#
# `betti_numbers_at_epsilon`, `diagram_cap`, `plot_barcodes` and `plot_persistence_diagram` know nothing about where a persistence diagram came from -- a point cloud, a graph, an image, or a 3D shape -- so every section below reuses them as-is. They also work for however many homology dimensions ($H_0$, $H_1$, optionally $H_2$) a given diagram happens to contain.

# %%
DIM_COLOURS = {0: "#457b9d", 1: "#e76f51", 2: "#6a4c93"}
DIM_NAMES = {0: "H0", 1: "H1", 2: "H2"}
DIM_COLOUR_NAMES = {0: "blue", 1: "orange", 2: "purple"}


def betti_numbers_at_epsilon(diagrams: List[np.ndarray], epsilon: float, max_dim: int = 1) -> Dict[int, int]:
    '''Compute Betti numbers by counting intervals alive at epsilon.'''
    betti: Dict[int, int] = {}
    for dim in range(min(max_dim + 1, len(diagrams))):
        alive = 0
        for birth, death in diagrams[dim]:
            if birth <= epsilon < death:
                alive += 1
        betti[dim] = alive
    return betti


def diagram_cap(diagrams: List[np.ndarray], filtration_max: float) -> float:
    '''Fixed upper limit for plotting finite/infinite deaths, so axes stay put while a slider moves.'''
    finite = [float(d) for dgm in diagrams for _, d in dgm if np.isfinite(d)]
    cap = 1.15 * max(finite) if finite else filtration_max + 0.1
    return max(cap, filtration_max + 0.1)


def plot_barcodes(ax: plt.Axes, diagrams: List[np.ndarray], value: float, cap: float, value_label: str = "ε") -> None:
    '''Plot barcodes for every homology dimension present and mark the current filtration value.'''
    ax.clear()
    row = 0
    for dim, dgm in enumerate(diagrams):
        colour = DIM_COLOURS.get(dim, "#333333")
        if len(dgm) > 0:
            dgm = dgm[np.argsort(dgm[:, 0])]
        for birth, death in dgm:
            end = cap if not np.isfinite(death) else float(death)
            ax.plot([birth, end], [row, row], color=colour, linewidth=2.0)
            if not np.isfinite(death):
                ax.plot(end, row, marker=">", color=colour, markersize=5)
            row += 1
        row += 1

    ax.axvline(value, linestyle="--", color="black", linewidth=1.3)
    legend = ",  ".join(
        f"{DIM_NAMES.get(d, f'H{d}')} = {DIM_COLOUR_NAMES.get(d, 'grey')}" for d in range(len(diagrams))
    )
    ax.text(0.01, 0.95, legend, transform=ax.transAxes, va="top", fontsize=8)
    ax.set_xlim(0.0, cap * 1.03)
    ax.set_ylim(-1, max(3, row))
    ax.set_xlabel(f"Filtration value {value_label}")
    ax.set_ylabel("Interval index")
    ax.set_title("Persistence barcodes")


def plot_persistence_diagram(ax: plt.Axes, diagrams: List[np.ndarray], value: float, cap: float) -> None:
    '''Plot the persistence diagram for every homology dimension present.'''
    ax.clear()
    ax.plot([0, cap], [0, cap], linestyle="--", color="grey", linewidth=1.0)

    for dim, dgm in enumerate(diagrams):
        if len(dgm) == 0:
            continue
        births = dgm[:, 0]
        deaths = np.where(np.isfinite(dgm[:, 1]), dgm[:, 1], cap)
        ax.scatter(
            births, deaths, s=28, alpha=0.9,
            label=DIM_NAMES.get(dim, f"H{dim}"), c=DIM_COLOURS.get(dim, "#333333"),
        )

    ax.axhline(value, linestyle=":", color="black", linewidth=1.0)
    ax.axvline(value, linestyle=":", color="black", linewidth=1.0)
    ax.set_xlim(0.0, cap * 1.03)
    ax.set_ylim(0.0, cap * 1.03)
    ax.set_xlabel("Birth")
    ax.set_ylabel("Death")
    ax.set_title("Persistence diagram")
    ax.legend(loc="lower right", fontsize=8)

# %% [markdown]
# ## 1. Vietoris-Rips complex for point clouds
#
# At each $\varepsilon$:
#
# 1. Points closer than $\varepsilon$ form edges (1-simplices).
# 2. Cliques of three connected points form filled triangles (2-simplices).
# 3. As $\varepsilon$ grows, components merge ($H_0$ intervals die) and loops appear/disappear ($H_1$ intervals are born/die).
#
# **Performance note.** The 2-simplex view used to get heavy for larger point clouds. It isn't the *triangle-finding* step that's slow -- that's cheap once you only look at each edge's neighbourhood instead of testing every $\binom{n}{3}$ triple -- it's *drawing* tens of thousands of individual translucent triangles one patch at a time. `build_vr_simplices` below finds triangles via adjacency-set intersection, and `plot_vr_complex` draws them as a single batched `PolyCollection` (capped at a few thousand on-screen triangles, with the true count always reported) -- so even a dense, near-complete graph on 150 points renders in well under a second.

# %%
def make_point_cloud(kind: str, n_points: int, noise: float, seed: int) -> np.ndarray:
    '''Create a 2D point cloud for interactive experiments.'''
    rng = np.random.default_rng(seed)

    if kind == "Noisy circle":
        t = np.linspace(0.0, 2.0 * np.pi, n_points, endpoint=False)
        pts = np.column_stack([np.cos(t), np.sin(t)])

    elif kind == "Two circles":
        n1 = n_points // 2
        n2 = n_points - n1
        t1 = np.linspace(0.0, 2.0 * np.pi, n1, endpoint=False)
        t2 = np.linspace(0.0, 2.0 * np.pi, n2, endpoint=False)
        c1 = np.column_stack([np.cos(t1), np.sin(t1)]) + np.array([-1.2, 0.0])
        c2 = 0.75 * np.column_stack([np.cos(t2), np.sin(t2)]) + np.array([1.2, 0.0])
        pts = np.vstack([c1, c2])

    elif kind == "Figure-eight":
        t = np.linspace(0.0, 2.0 * np.pi, n_points, endpoint=False)
        x = np.sin(t)
        y = np.sin(t) * np.cos(t)
        pts = np.column_stack([x, y])

    elif kind == "Three clusters":
        centres = np.array([[-1.3, -0.7], [1.2, -0.6], [0.0, 1.2]])
        splits = [n_points // 3, n_points // 3, n_points - 2 * (n_points // 3)]
        clouds = [
            rng.normal(loc=centres[i], scale=0.18, size=(splits[i], 2))
            for i in range(3)
        ]
        pts = np.vstack(clouds)

    else:
        raise ValueError(f"Unknown dataset kind: {kind}")

    if kind != "Three clusters" and noise > 0.0:
        pts = pts + rng.normal(scale=noise, size=pts.shape)

    # Small random jitter keeps points distinct when noise is tiny.
    pts = pts + rng.normal(scale=1e-4, size=pts.shape)
    return pts.astype(float)


@lru_cache(maxsize=256)
def cached_scene(kind: str, n_points: int, noise: float, seed: int):
    '''Cache point clouds, their pairwise distances, and PH diagrams so epsilon-only updates are fast.'''
    pts = make_point_cloud(kind=kind, n_points=n_points, noise=noise, seed=seed)
    dist = squareform(pdist(pts))
    dgms = ripser(pts, maxdim=1)["dgms"]
    return pts, dist, dgms


def build_vr_simplices(dist: np.ndarray, epsilon: float, max_display_triangles: int = 5000):
    '''Return the edges and 2-simplices of the VR complex at epsilon.

    Triangles are found by intersecting each edge's two neighbour sets rather
    than testing every C(n, 3) triple, and only up to `max_display_triangles`
    of them are handed to the renderer as a single PolyCollection. Drawing
    tens of thousands of individual overlapping patches is what made this
    view feel heavy, not the enumeration itself. The true count is always
    reported alongside the (possibly subsampled) display set.
    '''
    n = dist.shape[0]
    adj = dist <= epsilon
    np.fill_diagonal(adj, False)

    iu = np.triu_indices(n, k=1)
    edges = np.column_stack(iu)[adj[iu]]

    triangle_blocks = []
    for i in range(n - 2):
        neighbours = np.flatnonzero(adj[i, i + 1:]) + (i + 1)
        if neighbours.size < 2:
            continue
        sub = adj[np.ix_(neighbours, neighbours)]
        jj, kk = np.triu_indices(neighbours.size, k=1)
        hit = sub[jj, kk]
        if hit.any():
            triangle_blocks.append(
                np.column_stack([np.full(hit.sum(), i), neighbours[jj[hit]], neighbours[kk[hit]]])
            )
    triangles = np.vstack(triangle_blocks) if triangle_blocks else np.empty((0, 3), dtype=int)

    n_triangles = len(triangles)
    if n_triangles > max_display_triangles:
        rng = np.random.default_rng(0)
        keep = rng.choice(n_triangles, size=max_display_triangles, replace=False)
        triangles_display = triangles[keep]
    else:
        triangles_display = triangles

    return edges, triangles_display, n_triangles


def plot_vr_complex(
    ax: plt.Axes,
    points: np.ndarray,
    epsilon: float,
    edges: np.ndarray,
    triangles: np.ndarray,
    show_balls: bool,
) -> None:
    '''Draw the VR complex at a fixed epsilon.'''
    ax.clear()

    if show_balls:
        radius = epsilon / 2.0
        for x, y in points:
            ax.add_patch(Circle((x, y), radius=radius, facecolor="#a9def9", edgecolor="none", alpha=0.22, zorder=0))

    if len(triangles):
        ax.add_collection(
            PolyCollection(points[triangles], facecolor="#f4a261", edgecolor="none", alpha=0.35, zorder=1)
        )

    if len(edges):
        ax.add_collection(
            LineCollection(points[edges], colors="#2a9d8f", linewidths=1.25, alpha=0.95, zorder=2)
        )

    ax.scatter(points[:, 0], points[:, 1], s=22, c="#1d3557", edgecolors="white", linewidths=0.45, zorder=3)
    ax.set_aspect("equal")
    ax.set_title(f"Vietoris-Rips complex at ε = {epsilon:.2f}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")

    pad = 0.35
    x_min, x_max = points[:, 0].min() - pad, points[:, 0].max() + pad
    y_min, y_max = points[:, 1].min() - pad, points[:, 1].max() + pad
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)


def render_scene(
    kind: str,
    n_points: int,
    noise: float,
    seed: int,
    epsilon: float,
    show_balls: bool,
    show_triangles: bool,
) -> None:
    '''Render VR geometry, barcodes, and persistence diagram for one parameter setting.'''
    noise = float(np.round(noise, 4))
    points, dist, diagrams = cached_scene(kind, int(n_points), noise, int(seed))

    edges, triangles, n_triangles = build_vr_simplices(dist, epsilon)
    if not show_triangles:
        triangles = np.empty((0, 3), dtype=int)

    betti = betti_numbers_at_epsilon(diagrams, epsilon, max_dim=1)
    cap = diagram_cap(diagrams, filtration_max=2.4)

    fig = plt.figure(figsize=(13.5, 6.0))
    gs = fig.add_gridspec(2, 2, width_ratios=[1.22, 1.0], height_ratios=[1.0, 1.0], wspace=0.3, hspace=0.3)

    ax_complex = fig.add_subplot(gs[:, 0])
    ax_barcode = fig.add_subplot(gs[0, 1])
    ax_diag = fig.add_subplot(gs[1, 1])

    plot_vr_complex(ax_complex, points, epsilon, edges, triangles, show_balls=show_balls)
    plot_barcodes(ax_barcode, diagrams, epsilon, cap)
    plot_persistence_diagram(ax_diag, diagrams, epsilon, cap)

    summary = (
        f"Betti_0 = {betti.get(0, 0)}   |   "
        f"Betti_1 = {betti.get(1, 0)}   |   "
        f"vertices = {len(points)}, edges = {len(edges)}, triangles = {n_triangles}"
    )
    if n_triangles > len(triangles):
        summary += f"  (showing {len(triangles)} of {n_triangles})"
    ax_complex.text(
        0.02,
        0.98,
        summary,
        transform=ax_complex.transAxes,
        va="top",
        fontsize=9,
        bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "#cccccc"},
    )

    fig.suptitle("Persistent homology of a Vietoris-Rips filtration", fontsize=13)
    plt.show()
    plt.close(fig)


dataset = widgets.Dropdown(
    options=["Noisy circle", "Two circles", "Figure-eight", "Three clusters"],
    value="Noisy circle",
    description="Dataset:",
)

n_points = widgets.IntSlider(value=45, min=15, max=150, step=1, description="Points:", continuous_update=False)
noise = widgets.FloatSlider(value=0.06, min=0.0, max=0.25, step=0.01, description="Noise:", continuous_update=False)
seed = widgets.IntSlider(value=7, min=0, max=200, step=1, description="Seed:", continuous_update=False)
epsilon = widgets.FloatSlider(value=0.35, min=0.01, max=2.4, step=0.01, description="Epsilon:", continuous_update=False)
show_balls = widgets.Checkbox(value=True, description="Show epsilon/2 balls")
show_triangles = widgets.Checkbox(value=True, description="Fill 2-simplices")

ui = widgets.VBox([
    widgets.HBox([dataset, n_points, noise]),
    widgets.HBox([seed, epsilon, show_balls, show_triangles]),
])

out = widgets.interactive_output(
    render_scene,
    {
        "kind": dataset,
        "n_points": n_points,
        "noise": noise,
        "seed": seed,
        "epsilon": epsilon,
        "show_balls": show_balls,
        "show_triangles": show_triangles,
    },
)

display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# ## 2. Weighted graphs (1-dimensional simplicial complex)
#
# A point cloud is a special case of something more general: a **weighted graph**, where the "distance" between two nodes is just whatever number labels their edge (and most pairs may not be connected at all). Here we treat the graph itself *as* the simplicial complex: only vertices (0-simplices) and edges (1-simplices), stopping there -- we never add a 2-simplex, even when three edges happen to form a triangle. At threshold $t$, keep every edge of weight $\le t$.
#
# That "stop at dimension 1" choice has a clean consequence: with no 2-simplices, there is never anything available to fill a loop in with. So **every $H_1$ class that is ever born is permanent** -- $H_1$ simply counts independent cycles, exactly $|\text{active edges}| - |\text{vertices}| + |\text{components}|$ at any threshold, and it only ever grows to the right, never closes up. $H_0$ still behaves as usual: components merge and die as edges connect them.
#
# Edge weights below are deliberately spread out (not bunched near a single value) precisely so that moving the threshold slider visibly adds one edge at a time instead of everything happening at once. Three small examples:
#
# - **Two clusters + bridge**: a small dense cluster (a $K_4$: 4 nodes, all 6 edges present) joined by one expensive bridge edge to a sparse path cluster (4 nodes, 3 edges, a tree). The dense side alone contributes 3 permanent $H_1$ loops (6 edges - 4 vertices + 1 component); the tree side contributes none -- a tree never has a cycle. $H_0$ merges internally on both sides long before the bridge finally joins them into one component.
# - **Ring (one big loop)**: a bare cycle graph -- exactly one loop, born the instant the last ring edge appears, and it lives forever after that.
# - **Random weighted graph**: a sparser, less predictable graph with several components and several permanent loops of different sizes, born at different thresholds.

# %%
import gudhi
import networkx as nx


def make_weighted_graph(kind: str) -> Tuple[int, np.ndarray, List[Tuple[int, int, float]]]:
    '''Return (n_nodes, 2D layout positions, weighted edge list) for a small example graph.

    Edge weights are spread across a wide range on purpose, so that dragging
    the threshold slider adds edges one at a time instead of several at once.
    '''
    if kind == "Two clusters + bridge":
        rng = np.random.default_rng(0)
        theta = np.linspace(0.0, 2.0 * np.pi, 4, endpoint=False)
        square = np.column_stack([np.cos(theta), np.sin(theta)]) * 0.45
        pos_dense = square + np.array([-1.5, 0.0])
        pos_tree = np.column_stack([np.linspace(1.1, 2.3, 4), np.zeros(4)])
        pos = np.vstack([pos_dense, pos_tree])

        # Dense side: K4 (4 nodes, all 6 edges) -- a spanning tree needs only 3
        # of those edges, so the other 3 each close a permanent loop.
        dense_edges = [(i, j, float(rng.uniform(0.6, 2.6))) for i in range(4) for j in range(i + 1, 4)]
        # Sparse side: a path (4 nodes, 3 edges) -- a tree, so zero cycles.
        tree_edges = [(4, 5, float(rng.uniform(0.6, 2.6))),
                      (5, 6, float(rng.uniform(0.6, 2.6))),
                      (6, 7, float(rng.uniform(0.6, 2.6)))]
        bridge = [(1, 5, 4.0)]
        return 8, pos, dense_edges + tree_edges + bridge

    if kind == "Ring (one big loop)":
        n = 10
        theta = np.linspace(0.0, 2.0 * np.pi, n, endpoint=False)
        pos = np.column_stack([np.cos(theta), np.sin(theta)])
        edges = [(i, (i + 1) % n, 1.0 + 0.2 * i) for i in range(n)]
        return n, pos, edges

    if kind == "Random weighted graph":
        n = 14
        graph = nx.gnm_random_graph(n, 20, seed=2)
        layout = nx.spring_layout(graph, seed=2)
        pos = np.array([layout[i] for i in range(n)])
        rng = np.random.default_rng(2)
        edges = [(i, j, float(rng.uniform(0.2, 3.0))) for i, j in graph.edges()]
        return n, pos, edges

    raise ValueError(f"Unknown graph kind: {kind}")


def graph_persistence_diagrams(n: int, edges: List[Tuple[int, int, float]], maxdim: int = 1) -> List[np.ndarray]:
    '''Persistent homology of the graph as a 1-dimensional simplicial complex, via gudhi.

    Deliberately *not* calling `SimplexTree.expansion(...)`: the tree only ever
    holds vertices and edges, so no triangle can ever be added as a 2-simplex,
    however many of a triangle's three edges happen to be present. That is
    what makes every H1 class permanent -- there is nothing to fill it in
    with.

    Also note: `SimplexTree.persistence()` silently drops intervals in the
    complex's *top* dimension unless you ask for them explicitly, which
    matters a lot here since this complex's top dimension is 1 -- a bare
    cycle graph's one H1 class would otherwise vanish entirely.
    `persistence_intervals_in_dimension` avoids that trap.
    '''
    tree = gudhi.SimplexTree()
    for i in range(n):
        tree.insert([i], filtration=0.0)
    for i, j, w in edges:
        tree.insert([i, j], filtration=float(w))
    tree.compute_persistence(persistence_dim_max=True)
    return [
        np.asarray(tree.persistence_intervals_in_dimension(dim)).reshape(-1, 2)
        for dim in range(maxdim + 1)
    ]


def connected_components_at(n: int, edges: List[Tuple[int, int, float]], threshold: float) -> np.ndarray:
    '''Union-find over edges active at `threshold`, returning a component id per node.'''
    parent = list(range(n))

    def find(x: int) -> int:
        while parent[x] != x:
            parent[x] = parent[parent[x]]
            x = parent[x]
        return x

    for i, j, w in edges:
        if w <= threshold:
            ri, rj = find(i), find(j)
            if ri != rj:
                parent[ri] = rj

    roots = [find(i) for i in range(n)]
    relabel = {root: idx for idx, root in enumerate(sorted(set(roots)))}
    return np.array([relabel[r] for r in roots])


@lru_cache(maxsize=8)
def cached_graph_scene(kind: str, maxdim: int = 1):
    '''Cache the graph layout, edges, and PH diagrams for a named example.'''
    n, pos, edges = make_weighted_graph(kind)
    diagrams = graph_persistence_diagrams(n, edges, maxdim=maxdim)
    return n, pos, edges, diagrams


def plot_weighted_graph(ax: plt.Axes, pos: np.ndarray, n: int, edges, threshold: float) -> None:
    '''Draw the graph's 1-skeleton active up to `threshold`, colouring nodes by component.'''
    ax.clear()

    active_edges = np.array([(i, j) for i, j, w in edges if w <= threshold])
    inactive_edges = np.array([(i, j) for i, j, w in edges if w > threshold])

    if len(inactive_edges):
        ax.add_collection(
            LineCollection(pos[inactive_edges], colors="#cccccc", linewidths=1.0, linestyles="dashed", alpha=0.7, zorder=1)
        )
    if len(active_edges):
        ax.add_collection(LineCollection(pos[active_edges], colors="#2a9d8f", linewidths=2.2, zorder=2))

    component = connected_components_at(n, edges, threshold)
    colours = plt.get_cmap("tab10")(component % 10)
    ax.scatter(pos[:, 0], pos[:, 1], s=160, c=colours, edgecolors="white", linewidths=1.3, zorder=3)
    for idx, (x, y) in enumerate(pos):
        ax.text(x, y, str(idx), ha="center", va="center", fontsize=8, zorder=4, color="white", fontweight="bold")

    ax.set_aspect("equal")
    ax.set_title(f"Weighted graph (1-skeleton) at t = {threshold:.2f}")
    ax.set_xticks([])
    ax.set_yticks([])
    pad = 0.4
    ax.set_xlim(pos[:, 0].min() - pad, pos[:, 0].max() + pad)
    ax.set_ylim(pos[:, 1].min() - pad, pos[:, 1].max() + pad)


def render_graph_scene(kind: str, threshold: float) -> None:
    '''Render a weighted graph's 1-dimensional filtration alongside its barcode and diagram.'''
    n, pos, edges, diagrams = cached_graph_scene(kind)
    betti = betti_numbers_at_epsilon(diagrams, threshold, max_dim=1)
    n_components = len(set(connected_components_at(n, edges, threshold)))
    filtration_max = max(w for _, _, w in edges)
    cap = diagram_cap(diagrams, filtration_max=filtration_max)

    fig = plt.figure(figsize=(13.5, 6.0))
    gs = fig.add_gridspec(2, 2, width_ratios=[1.22, 1.0], height_ratios=[1.0, 1.0], wspace=0.3, hspace=0.3)

    ax_graph = fig.add_subplot(gs[:, 0])
    ax_bar = fig.add_subplot(gs[0, 1])
    ax_diag = fig.add_subplot(gs[1, 1])

    plot_weighted_graph(ax_graph, pos, n, edges, threshold)
    plot_barcodes(ax_bar, diagrams, threshold, cap, value_label="t")
    plot_persistence_diagram(ax_diag, diagrams, threshold, cap)

    summary = f"Betti_0 = {betti.get(0, 0)}   |   Betti_1 = {betti.get(1, 0)}   |   components = {n_components}"
    ax_graph.text(
        0.02, 0.98, summary, transform=ax_graph.transAxes, va="top", fontsize=9,
        bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "#cccccc"},
    )

    fig.suptitle(f"Persistent homology of a 1-dimensional weighted graph: {kind}", fontsize=13)
    plt.show()
    plt.close(fig)


graph_dataset = widgets.Dropdown(
    options=["Two clusters + bridge", "Ring (one big loop)", "Random weighted graph"],
    value="Two clusters + bridge",
    description="Graph:",
)
graph_threshold = widgets.FloatSlider(
    value=1.0, min=0.0, max=5.0, step=0.02, description="Threshold:", continuous_update=False,
)


def _resize_graph_threshold(change=None):
    '''Rescale the threshold slider to the current graph's actual weight range.'''
    kind = graph_dataset.value
    _, _, edges, _ = cached_graph_scene(kind)
    graph_threshold.max = round(max(w for _, _, w in edges) * 1.15, 2)
    graph_threshold.value = min(graph_threshold.value, graph_threshold.max)


graph_dataset.observe(_resize_graph_threshold, names="value")
_resize_graph_threshold()

graph_ui = widgets.HBox([graph_dataset, graph_threshold])
graph_out = widgets.interactive_output(
    render_graph_scene, {"kind": graph_dataset, "threshold": graph_threshold},
)

display(graph_ui, graph_out)
# Out:
# ...
# Output()

# %% [markdown]
# ## 3. Cubical complexes for 1D signals and 2D images
#
# We use a **sublevel-set filtration**: cells with value $\le t$ are active at threshold $t$.
#
# - In **1D**, this is a filtered signal.
# - In **2D**, this is a filtered image / height map.
#
# The two synthetic 2D toys below are a gentle warm-up, but the real point of this section is the two **real, non-trivial images**:
#
# - **`coins`** (from `skimage`): negate and lightly smooth the photo so the ~24 bright coins become the *low* values (born first). $H_0$ persistence then does exactly what persistent homology is famous for in image analysis -- separating "real objects" (long bars) from lighting/texture noise (short bars), effectively **counting the coins**.
# - **`TOPOLOGY` (rendered as an image)**: a signed distance field from the word's own outline. $H_1$ finds exactly the letters with an enclosed hole -- the three **O**s and the **P** -- while `T`, `L`, `G`, `Y` correctly contribute nothing. A nice, on-theme, verifiable example: 8 letters ⇒ $H_0=8$, 4 holes ⇒ $H_1=4$.

# %%
import cripser
import matplotlib.font_manager as fm
import skimage.data
from PIL import Image, ImageDraw, ImageFont
from scipy.ndimage import distance_transform_edt, gaussian_filter
from skimage.filters import threshold_otsu


def _normalise01(arr: np.ndarray) -> np.ndarray:
    '''Scale an array to [0, 1] for consistent threshold controls.'''
    arr = np.asarray(arr, dtype=float)
    lo, hi = float(arr.min()), float(arr.max())
    if hi <= lo:
        return np.zeros_like(arr)
    return (arr - lo) / (hi - lo)


def _render_text_image(text: str, font_size: int = 90, pad: int = 15) -> np.ndarray:
    '''Rasterise `text` with a bold font, cropped tightly around its own bounding box.'''
    font = ImageFont.truetype(fm.findfont(fm.FontProperties(family="DejaVu Sans", weight="bold")), font_size)
    probe = ImageDraw.Draw(Image.new("L", (10, 10)))
    left, top, right, bottom = probe.textbbox((0, 0), text, font=font)
    width, height = right - left + 2 * pad, bottom - top + 2 * pad

    image = Image.new("L", (width, height), color=255)
    ImageDraw.Draw(image).text((pad - left, pad - top), text, font=font, fill=0)
    return np.array(image, dtype=float)


def make_cubical_array(kind: str) -> np.ndarray:
    '''Create small 1D/2D arrays for cubical PH demos, from toy signals to real images.'''
    if kind == "1D: two valleys":
        arr = np.array([0.94, 0.78, 0.60, 0.38, 0.20, 0.35, 0.62, 0.86,
                        0.91, 0.66, 0.33, 0.18, 0.31, 0.58, 0.81, 0.95])
        return _normalise01(arr)

    if kind == "1D: wavy signal":
        x = np.linspace(-1.0, 1.0, 20)
        arr = 0.50 + 0.30 * np.sin(2.7 * np.pi * x) + 0.15 * np.cos(5.5 * np.pi * x)
        return _normalise01(arr)

    yy, xx = np.mgrid[-1.0:1.0:24j, -1.0:1.0:24j]

    if kind == "2D: two basins":
        b1 = (xx + 0.48) ** 2 + (yy - 0.05) ** 2
        b2 = (xx - 0.52) ** 2 + (yy + 0.02) ** 2
        arr = np.minimum(b1, b2) + 0.08 * (xx ** 2 + yy ** 2)
        return _normalise01(arr)

    if kind == "2D: ring valley":
        rr = np.sqrt(xx ** 2 + yy ** 2)
        arr = (rr - 0.56) ** 2 + 0.10 * rr
        return _normalise01(arr)

    if kind == "Image: coins (H0 counts objects)":
        # Coins are bright, so negate to make them the sublevel-set minima (born first).
        # A moderate blur washes out the embossed texture on each coin without
        # blurring coins into each other -- without it, PH also finds thousands
        # of tiny texture-driven components and completely buries the real signal.
        smoothed = gaussian_filter(skimage.data.coins().astype(float), sigma=4.0)
        return _normalise01(-smoothed)[::-1]

    if kind == "Image: TOPOLOGY (H1 finds letter holes)":
        image = _render_text_image("TOPOLOGY")
        ink = image < 128
        signed_distance = distance_transform_edt(~ink) - distance_transform_edt(ink)
        return _normalise01(signed_distance)[::-1]

    raise ValueError(f"Unknown cubical dataset: {kind}")


@lru_cache(maxsize=32)
def cached_cubical_scene(kind: str, maxdim: int = 1):
    '''Cache arrays and their cubical persistence outputs.'''
    arr = make_cubical_array(kind)
    rows = cripser.compute_ph(arr, filtration="V", maxdim=maxdim, location="yes")

    diagrams: List[np.ndarray] = []
    if rows.size == 0:
        diagrams = [np.empty((0, 2), dtype=float) for _ in range(maxdim + 1)]
    else:
        dims = rows[:, 0].astype(int)
        for dim in range(maxdim + 1):
            block = rows[dims == dim][:, 1:3]
            if block.size == 0:
                block = np.empty((0, 2), dtype=float)
            diagrams.append(block)

    return arr, diagrams


def plot_cubical_field(ax_val: plt.Axes, ax_mask: plt.Axes, arr: np.ndarray, threshold: float) -> None:
    '''Plot scalar values and current sublevel-set mask for 1D or 2D arrays.'''
    ax_val.clear()
    ax_mask.clear()

    if arr.ndim == 1:
        x = np.arange(arr.shape[0])
        active = arr <= threshold

        ax_val.plot(x, arr, color="#1d3557", linewidth=1.8)
        ax_val.scatter(x[~active], arr[~active], c="#8d99ae", s=35, label="inactive")
        ax_val.scatter(x[active], arr[active], c="#2a9d8f", s=42, label="active")
        ax_val.axhline(threshold, linestyle="--", color="black", linewidth=1.2)
        ax_val.set_title("1D scalar signal")
        ax_val.set_xlabel("Index")
        ax_val.set_ylabel("Value")
        ax_val.set_ylim(-0.05, 1.05)
        ax_val.legend(loc="upper right", fontsize=8)

        mask_img = active.astype(float)[None, :]
        ax_mask.imshow(mask_img, cmap="Greens", vmin=0.0, vmax=1.0, aspect="auto", origin="lower")
        ax_mask.set_title("Sublevel set (value ≤ t)")
        ax_mask.set_xlabel("Index")
        ax_mask.set_yticks([])

    elif arr.ndim == 2:
        mask = arr <= threshold

        ax_val.imshow(arr, cmap="gray", vmin=0.0, vmax=1.0, origin="lower")
        ax_val.contour(arr, levels=[threshold], colors="#e76f51", linewidths=1.2)
        ax_val.set_title("Filtration field")
        ax_val.set_xlabel("x")
        ax_val.set_ylabel("y")

        ax_mask.imshow(mask.astype(float), cmap="Greens", vmin=0.0, vmax=1.0, origin="lower")
        ax_mask.set_title("Sublevel set (value ≤ t)")
        ax_mask.set_xlabel("x")
        ax_mask.set_ylabel("y")

    else:
        raise ValueError("Only 1D and 2D arrays are supported in this demo.")


def render_cubical_scene(kind: str, threshold: float) -> None:
    '''Render cubical filtration visuals with barcodes and persistence diagram.'''
    arr, diagrams = cached_cubical_scene(kind, maxdim=1)
    betti = betti_numbers_at_epsilon(diagrams, threshold, max_dim=1)
    active_cells = int((arr <= threshold).sum())
    cap = diagram_cap(diagrams, filtration_max=1.0)

    fig = plt.figure(figsize=(13.5, 6.4))
    gs = fig.add_gridspec(2, 2, width_ratios=[1.22, 1.0], height_ratios=[1.0, 1.0], wspace=0.3, hspace=0.3)

    ax_val = fig.add_subplot(gs[0, 0])
    ax_mask = fig.add_subplot(gs[1, 0])
    ax_bar = fig.add_subplot(gs[0, 1])
    ax_diag = fig.add_subplot(gs[1, 1])

    plot_cubical_field(ax_val, ax_mask, arr, threshold)
    plot_barcodes(ax_bar, diagrams, threshold, cap, value_label="t")
    plot_persistence_diagram(ax_diag, diagrams, threshold, cap)

    summary = (
        f"Betti_0 = {betti.get(0, 0)}   |   "
        f"Betti_1 = {betti.get(1, 0)}   |   "
        f"active cells = {active_cells}/{arr.size}"
    )
    ax_mask.text(
        0.02,
        0.98,
        summary,
        transform=ax_mask.transAxes,
        va="top",
        fontsize=9,
        bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "#cccccc"},
    )

    fig.suptitle(f"Cubical complex PH (sublevel filtration): {kind}", fontsize=13)
    plt.show()
    plt.close(fig)


cubical_dataset = widgets.Dropdown(
    options=[
        "1D: two valleys",
        "1D: wavy signal",
        "2D: two basins",
        "2D: ring valley",
        "Image: coins (H0 counts objects)",
        "Image: TOPOLOGY (H1 finds letter holes)",
    ],
    value="Image: coins (H0 counts objects)",
    description="Array:",
)

threshold = widgets.FloatSlider(
    value=0.35,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Threshold:",
    continuous_update=False,
)

cubical_ui = widgets.VBox([widgets.HBox([cubical_dataset, threshold])])

cubical_out = widgets.interactive_output(
    render_cubical_scene,
    {
        "kind": cubical_dataset,
        "threshold": threshold,
    },
)

display(cubical_ui, cubical_out)
# Out:
# ...
# Output()

# %% [markdown]
# ## 4. Bonus: 3D point clouds and $H_2$ (enclosed voids)
#
# Every example so far stopped at $H_1$ (loops). If we sample points from the surface of a simple 3D shape -- think of them as the vertices of a coarse triangulated mesh -- and let `ripser` go up to `maxdim=2`, a new kind of feature appears: $H_2$, an enclosed 2D void.
#
# - **Sphere**: simply connected ($H_1$ should be trivial, though a coarse/noisy sample always shows a few short-lived spurious loops), but it encloses one cavity. Watch for a single, clearly long-lived purple $H_2$ bar once $\varepsilon$ is large enough to close up the shell -- everything shorter is noise from the finite sample.
# - **Torus**: theoretically $H_0=1$, $H_1=2$ (the two independent loops around the hole and through the tube), $H_2=1$ (the enclosed volume). The two $H_1$ generators are genuinely harder to tell apart from noise with a modest point sample than the sphere's void is -- a good excuse to try more points / less noise yourself.

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401  (registers the '3d' projection)
from mpl_toolkits.mplot3d.art3d import Line3DCollection


def make_3d_point_cloud(kind: str, n_points: int, noise: float, seed: int) -> np.ndarray:
    '''Sample points from the surface of a simple 3D shape (vertices of a coarse mesh).'''
    rng = np.random.default_rng(seed)

    if kind == "Sphere":
        vecs = rng.normal(size=(n_points, 3))
        pts = vecs / np.linalg.norm(vecs, axis=1, keepdims=True)

    elif kind == "Torus":
        u = rng.uniform(0.0, 2.0 * np.pi, n_points)
        v = rng.uniform(0.0, 2.0 * np.pi, n_points)
        major, minor = 1.0, 0.45
        pts = np.column_stack([
            (major + minor * np.cos(v)) * np.cos(u),
            (major + minor * np.cos(v)) * np.sin(u),
            minor * np.sin(v),
        ])

    else:
        raise ValueError(f"Unknown 3D dataset: {kind}")

    pts = pts + rng.normal(scale=noise, size=pts.shape)
    return pts.astype(float)


@lru_cache(maxsize=64)
def cached_3d_scene(kind: str, n_points: int, noise: float, seed: int):
    '''Cache 3D point clouds, their pairwise distances, and PH diagrams up to H2.'''
    pts = make_3d_point_cloud(kind, n_points, noise, seed)
    dist = squareform(pdist(pts))
    dgms = ripser(pts, maxdim=2)["dgms"]
    return pts, dist, dgms


def plot_3d_point_cloud(ax: plt.Axes, points: np.ndarray, dist: np.ndarray, epsilon: float) -> None:
    '''Draw the point cloud plus its VR edges at epsilon (triangles are omitted -- see text).'''
    ax.clear()
    n = len(points)
    iu = np.triu_indices(n, k=1)
    active = dist[iu] <= epsilon
    if active.any():
        pairs = np.column_stack(iu)[active]
        ax.add_collection3d(Line3DCollection(points[pairs], colors="#2a9d8f", linewidths=0.5, alpha=0.4))

    ax.scatter(points[:, 0], points[:, 1], points[:, 2], s=16, c="#1d3557", depthshade=True)
    ax.set_title(f"Point cloud + edges at ε = {epsilon:.2f}")
    ranges = np.maximum(np.ptp(points, axis=0), 1e-3)
    ax.set_box_aspect(tuple(ranges))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_zticklabels([])
    ax.view_init(elev=25, azim=45)


def render_3d_scene(kind: str, n_points: int, noise: float, seed: int, epsilon: float) -> None:
    '''Render a 3D point cloud alongside its H0/H1/H2 barcode and persistence diagram.'''
    points, dist, diagrams = cached_3d_scene(kind, int(n_points), float(np.round(noise, 4)), int(seed))
    betti = betti_numbers_at_epsilon(diagrams, epsilon, max_dim=2)
    cap = diagram_cap(diagrams, filtration_max=2.2)

    fig = plt.figure(figsize=(13.5, 6.0))
    gs = fig.add_gridspec(2, 2, width_ratios=[1.22, 1.0], height_ratios=[1.0, 1.0], wspace=0.3, hspace=0.3)

    ax_cloud = fig.add_subplot(gs[:, 0], projection="3d")
    ax_bar = fig.add_subplot(gs[0, 1])
    ax_diag = fig.add_subplot(gs[1, 1])

    plot_3d_point_cloud(ax_cloud, points, dist, epsilon)
    plot_barcodes(ax_bar, diagrams, epsilon, cap)
    plot_persistence_diagram(ax_diag, diagrams, epsilon, cap)

    summary = f"Betti_0={betti.get(0, 0)}  Betti_1={betti.get(1, 0)}  Betti_2={betti.get(2, 0)}   |   points={len(points)}"
    ax_cloud.text2D(
        0.02, 0.98, summary, transform=ax_cloud.transAxes, va="top", fontsize=9,
        bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "#cccccc"},
    )

    fig.suptitle(f"Persistent homology of a 3D point cloud: {kind}", fontsize=13)
    plt.show()
    plt.close(fig)


shape_3d = widgets.Dropdown(options=["Sphere", "Torus"], value="Sphere", description="Shape:")
n_points_3d = widgets.IntSlider(value=100, min=40, max=150, step=5, description="Points:", continuous_update=False)
noise_3d = widgets.FloatSlider(value=0.02, min=0.0, max=0.1, step=0.005, description="Noise:", continuous_update=False)
seed_3d = widgets.IntSlider(value=0, min=0, max=50, step=1, description="Seed:", continuous_update=False)
epsilon_3d = widgets.FloatSlider(value=1.0, min=0.05, max=2.4, step=0.02, description="Epsilon:", continuous_update=False)

ui_3d = widgets.VBox([
    widgets.HBox([shape_3d, n_points_3d, noise_3d]),
    widgets.HBox([seed_3d, epsilon_3d]),
])

out_3d = widgets.interactive_output(
    render_3d_scene,
    {"kind": shape_3d, "n_points": n_points_3d, "noise": noise_3d, "seed": seed_3d, "epsilon": epsilon_3d},
)

display(ui_3d, out_3d)
# Out:
# ...
# Output()
